# %%
import os
os.chdir("..")

import os

# %%
os.environ["CONFIG_APP_DIR"] = "config"
import json
import re
import grpc
import random

random.randint(1, 100000)

from etl_pipeline.learning.proto.historical_decision_learning_pb2 import Alert, AlertedParty, HistoricalDecisionLearningStoreExchangeRequest
from etl_pipeline.learning.proto.etl_learning_pb2 import LearningMatch, LearningAlert, RunEtlLearningRequest
from etl_pipeline.learning.proto.etl_learning_pb2_grpc import EtlLearningServiceStub


def load_alert(filepath: str = "notebooks/sample/wm_address_in_payload_format.json"):
    with open(filepath, "r") as f:
        text = json.load(f)
        ids = [
            text[i]
            for key in text
            for i in re.compile(r".*matchRecords\[\d+\].matchId.*").findall(key)
            if i
        ]
        matches_ids = [
            LearningMatch(match_id=i, match_name=f"alerts/2/matches/{random.randint(1, 100000)}") for num, i in enumerate(ids)
        ]
        alert = LearningAlert(batch_id="1", alert_name="alerts/2", learning_matches=matches_ids)
        for key, value in text.items():
            alert.flat_payload[str(key)] = str(value)
    with open("notebooks/sample/event_history.json", "r") as f:
        text = json.load(f)
        for i in text['alertEventHistory']['eventHistory']:
            i['createDate'] = random_date(START, END)
        alert.alert_event_history = json.dumps(text)
    return alert

request_alert = load_alert("notebooks/sample/wm_address_in_payload_format.json")

# %%
from random import randrange
from datetime import timedelta

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return datetime.strftime(start + timedelta(seconds=random_second), "%Y-%m-%d %H:%M:%S.%f")

# %%
from datetime import datetime

START = datetime.strptime('1/1/2020 1:30 PM', '%m/%d/%Y %I:%M %p')
END = datetime.strptime('1/1/2022 4:50 AM', '%m/%d/%Y %I:%M %p')

print(random_date(d1, d2))
# Out:
# 2021-05-12 16:20:33.000000

# %%
for i in text['alertEventHistory']['eventHistory']:
    i['createDate'] = random_date(START, END)

# %%
channel = grpc.insecure_channel("10.8.0.3:23782")

# %%
channel1 = grpc.insecure_channel("10.8.0.3:26989")

# %%
channel = grpc.insecure_channel("10.8.0.3:22984")

# %%
stub = EtlLearningServiceStub(channel)

# %%
stub1 = EtlLearningServiceStub(channel1)

# %%
results_from_stub.append(stub.RunEtlLearning.future(RunEtlLearningRequest(learning_alerts=[request_alert for i in range(10)])))

# %%
results_from_stub = []
for i in range(500):
    results_from_stub.append(stub.RunEtlLearning.future(RunEtlLearningRequest(learning_alerts=[load_alert("notebooks/sample/wm_address_in_payload_format.json") for i in range(10)])))

# %%
results_from_stub1 = []
for i in range(1):
    results_from_stub1.append(stub1.RunEtlLearning.future(RunEtlLearningRequest(learning_alerts=[request_alert for i in range(10)])))

# %%
results_from_stub1 = [i.result() for i in results_from_stub1]

# %%
results_from_stub = [i.result() for i in results_from_stub]

# %%
len(results_from_stub)
# Out:
# 10

# %%
from google.protobuf.json_format import MessageToDict

# %%
counter = 0
for result in results_from_stub:
    result = MessageToDict(result)
    for item in result['etlAlerts']:
        assert item['etlStatus'] == 'SUCCESS'
        counter += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_250319/3722248443.py in <module>
#       1 counter = 0
#       2 for result in results_from_stub:
# ----> 3     result = MessageToDict(result)
#       4     for item in result['etlAlerts']:
#       5         assert item['etlStatus'] == 'SUCCESS'
#
# ~/repos/silenteight/venv2/lib/python3.7/site-packages/google/protobuf/json_format.py in MessageToDict(message, including_default_value_fields, preserving_proto_field_name, use_integers_for_enums, descriptor_pool, float_precision)
#     163       float_precision=float_precision)
#     164   # pylint: disable=protected-access
# --> 165   return printer._MessageToJsonObject(message)
#     166
#     167
#
# ~/repos/silenteight/venv2/lib/python3.7/site-packages/google/protobuf/json_format.py in _MessageToJsonObject(self, message)
#     197   def _MessageToJsonObject(self, message):
#     198     """Converts message to an object according to Proto3 JSON Specification."""
# --> 199     message_descriptor = message.DESCRIPTOR
#     200     full_name = message_descriptor.full_name
#     201     if _IsWrapperMessage(message_descriptor):
#
# AttributeError: '_MultiThreadedRendezvous' object has no attribute 'DESCRIPTOR'

# %%
counter
# Out:
# 0

# %%
assert counter == 10
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_250319/214008040.py in <module>
# ----> 1 assert counter == 10
#
# AssertionError:

# %%
counter = 0
for result in results_from_stub1:
    result = MessageToDict(result)
    for item in result['etlAlerts']:
        assert item['etlStatus'] == 'SUCCESS'
        counter += 1

# %%
assert counter == 2500

# %%
decompressed = lz4.frame.decompress(test.state)
# Out:
# ---------------------------------------------------
# TypeError         Traceback (most recent call last)
# <ipython-input-69-56cfc20ea28e> in <module>
# ----> 1 decompressed = lz4.frame.decompress(test.state)
#
# TypeError: a bytes-like object is required, not 'NoneType'

# %%
import lz4


from etl_pipeline.learning.proto.historical_decision_learning_pb2 import (
    Alert,
    AlertedParty,
    HistoricalDecisionLearningStoreExchangeRequest,
)
x = HistoricalDecisionLearningStoreExchangeRequest()
x.FromString(decompressed)
# Out:
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }

# %%
new_field = field_type()
feature.agent_feature_input.Unpack(new_field)

# %%
payload = """"""

# %%
import lz4.frame

# %%
import base64
output = base64.b64decode(payload)

# %%
x = HistoricalDecisionLearningStoreExchangeRequest()
x.ParseFromString(lz4.frame.decompress(output))
# Out:
# 3432

# %%
x
# Out:
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
