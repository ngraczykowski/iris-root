# %%
import os
os.chdir("..")

import os

# %%
os.environ["CONFIG_APP_DIR"] = "config"
import json
import re
import grpc
import random
from etl_pipeline.learning.service import ANALYST_DECISION_MAP
random.randint(1, 100000)

from etl_pipeline.learning.proto.historical_decision_learning_pb2 import Alert, AlertedParty, HistoricalDecisionLearningStoreExchangeRequest
from etl_pipeline.learning.proto.etl_learning_pb2 import LearningMatch, LearningAlert, RunEtlLearningRequest
from etl_pipeline.learning.proto.etl_learning_pb2_grpc import EtlLearningServiceStub


def load_alert(filepath: str = "notebooks/sample/wm_address_in_payload_format.json"):
    with open(filepath, "r") as f:
        text = json.load(f)
        ids = [
            text[i]
            for key in text
            for i in re.compile(r".*matchRecords\[\d+\].matchId.*").findall(key)
            if i
        ]
        matches_ids = [
            LearningMatch(match_id=f"{random.randint(1, 100000)}", match_name=f"{random.randint(1, 100000)}") for num, i in enumerate(ids)
        ]
        
        alert = LearningAlert(batch_id="1", alert_name="alerts/2", learning_matches=matches_ids)
        for key, value in text.items():
            alert.flat_payload[str(key)] = str(value)
        alert.flat_payload["watchlistParty.matchRecords[0].matchId"] = str(matches_ids[0].match_id)
        alert.flat_payload["watchlistParty.matchRecords[1].matchId"] = str(matches_ids[1].match_id)
    with open("notebooks/sample/event_history.json", "r") as f:
        text = json.load(f)
        for i in text['alertEventHistory']['eventHistory']:
            i['createDate'] = random_date(START, END)
        text['alertEventHistory']['alertId'] = f"SANC-ASM-{random.randint(1, 100000)}"
        text['alertEventHistory']['statusName'] = random.choice(list(ANALYST_DECISION_MAP.keys()))
        alert.alert_event_history = json.dumps(text)
    return alert

request_alert = load_alert("notebooks/sample/wm_address_in_payload_format.json")
# Out:
# /home/artur/repos/silenteight/venv2/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# The following fields have not been found in any file:
# ['AP_TAX_IDS', 'ADDRESS1_CITY', 'PARTY1_COUNTRY1_CITIZENSHIP', 'PARTY1_NAME_ALIAS4', 'ADDRESS1_PROVINCE', 'AP_ACCOUNT_BENEFICIARY_NAMES', 'ADDRESS1_STATE', 'AP_PARTY_BIRTH_COUNTRIES', 'PARTY1_ADDRESS1_COUNTRY', 'AP_COUNTRY_OF_INCORPORATION', 'COUNTRY_CODE', 'PARTY1_EMPLOYER', 'AP_PARTY_RESIDENCY_COUNTRIES', 'UNIQUE_KEY', 'PARTY1_POSITION_TITLE', 'PARTY1_COUNTRY2_CITIZENSHIP', 'PARTY1_GOVTID1_NUMBER', 'PARTY1_ADDRESS1_STATE', 'PARTY1_COUNTRY_PEP', 'PARTY1_ID', 'PARTY1_COUNTRY', 'PARTY1_COUNTRY_CITIZENSHIP1', 'COUNTRY1_CITIZENSHIP', 'PARTY1_GOVTID2_NUMBER', 'COUNTRY_DOMICILE1', 'AP_PARTY_CITIZENSHIP_COUNTRIES', 'PARTY1_NAME_ALIAS1', 'ADDRESS1_COUNTRY', 'PARTY1_COUNTRY_OF_INCORPORATION', 'PARTY1_COUNTRY1', 'PARTY1_NAME_FULL', 'COUNTRY2_CITIZENSHIP', 'CONCAT_NAME', 'PARTY1_ADDRESS1_CITY', 'PARTY1_NAME_ALIAS2', 'COUNTRY1', 'ACCOUNTNUMBER', 'AP_GOVT_IDS', 'PARTY1_COUNTRY_DOMICILE1', 'PARTY1_NAME_ALIAS3', 'PARTY1_COUNTRY_FORMATION1', 'AP_DOB']
# Field in agent configuration for: PARTY1_COUNTRY1 is not registered field in pipeline.yaml
# Field in agent configuration for: PARTY1_COUNTRY1 is not registered field in pipeline.yaml
# Field in agent configuration for: PARTY1_COUNTRY1 is not registered field in pipeline.yaml
# Field in agent configuration for: PARTY1_COUNTRY is not registered field in pipeline.yaml
# Field in agent configuration for: PARTY1_COUNTRY1 is not registered field in pipeline.yaml

# %%
request_alert
# Out:
# batch_id: "1"
# alert_name: "alerts/2"
# learning_matches {
#   match_id: "66326"
#   match_name: "15838"
# }
# learning_matches {
#   match_id: "38741"
#   match_name: "88585"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.currentVersionId"
#   value: "122438658"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.datasetId"
#   value: "1044"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.datasetName"
#   value: "R_US_Active_Address"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.firstVersionCreatedDt"
#   value: "2020-01-08T09:31:30.264-05:00"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.inputVersionSample"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06."
# }
# flat_payload {
#   key: "alertedParty.headerInfo.lastVersionUpdatedDt"
#   value: "2020-01-08T09:31:30.264-05:00"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.masterId"
#   value: "72951854"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.masterVersion"
#   value: "412740c151535f0756e8dbec7440b726c7a3e135"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.stopDescriptors.stopDescriptor.name"
#   value: "Joe Doe"
# }
# flat_payload {
#   key: "alertedParty.headerInfo.uniqueCustomerId"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].createdDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[0].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[0].name"
#   value: "SOURCE_REF"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[0].sortOrder"
#   value: "1"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[0].value"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[10].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[10].name"
#   value: "ADDRESS1_LINE5"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[10].sortOrder"
#   value: "11"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[11].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[11].name"
#   value: "ADDRESS1_LINE6"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[11].sortOrder"
#   value: "12"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[12].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[12].name"
#   value: "CONCAT_ADDRESS"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[12].sortOrder"
#   value: "13"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[12].value"
#   value: "Joe Black & Jane Doe 111 A 11TH ST AAA 1A New Jersey NJ"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[13].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[13].name"
#   value: "ADDRESS1_CITY"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[13].sortOrder"
#   value: "14"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[14].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[14].name"
#   value: "ADDRESS1_STATE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[14].sortOrder"
#   value: "15"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[15].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[15].name"
#   value: "ADDRESS1_PROVINCE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[15].sortOrder"
#   value: "16"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[16].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[16].name"
#   value: "ADDRESS1_POSTALCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[16].sortOrder"
#   value: "17"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[17].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[17].name"
#   value: "ADDRESS1_ZIP5"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[17].sortOrder"
#   value: "18"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[18].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[18].name"
#   value: "ADDRESS1_ZIP4"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[18].sortOrder"
#   value: "19"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[19].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[19].name"
#   value: "ADDRESS1_COUNTRY"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[19].sortOrder"
#   value: "20"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[19].value"
#   value: "UNITED STATES OF AMERICA"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[1].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[1].name"
#   value: "UNIQUE_KEY"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[1].sortOrder"
#   value: "2"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[1].value"
#   value: "A05003324172"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[20].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[20].name"
#   value: "ADDRESS1_COUNTRYCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[20].sortOrder"
#   value: "21"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[20].value"
#   value: "USA"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[21].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[21].name"
#   value: "ADDRESS1_FOREIGNDOMESTICCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[21].sortOrder"
#   value: "22"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[21].value"
#   value: "DOMESTIC"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[22].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[22].name"
#   value: "PARTY1_NAME_FULL"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[22].sortOrder"
#   value: "22"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[22].value"
#   value: "Janusz"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[23].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[23].name"
#   value: "CONCAT_NAME"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[23].sortOrder"
#   value: "13"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[23].value"
#   value: "Joe BlackJ"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[2].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[2].name"
#   value: "BARCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[2].sortOrder"
#   value: "3"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[3].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[3].name"
#   value: "ADDRESS_TYPE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[3].sortOrder"
#   value: "4"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[3].value"
#   value: "Plating Address"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[4].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[4].name"
#   value: "CARE_OF_TEXT"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[4].sortOrder"
#   value: "5"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[5].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[5].name"
#   value: "ATTENTION_TO_TEXT"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[5].sortOrder"
#   value: "6"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[6].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[6].name"
#   value: "ADDRESS1_LINE1"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[6].sortOrder"
#   value: "7"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[6].value"
#   value: "Joe Black &"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[7].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[7].name"
#   value: "ADDRESS1_LINE2"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[7].sortOrder"
#   value: "8"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[7].value"
#   value: "Jane Doe AA BBB"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[8].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[8].name"
#   value: "ADDRESS1_LINE3"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[8].sortOrder"
#   value: "9"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[8].value"
#   value: "111 A 11TH ST AAA 1A"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[9].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[9].name"
#   value: "ADDRESS1_LINE4"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[9].sortOrder"
#   value: "10"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].fields[9].value"
#   value: "New Jersey NJ 10011"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].masterId"
#   value: "72951854"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].status"
#   value: "A"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].uniqueCustId"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].version"
#   value: "412740c151535f0756e8dbec7440b726c7a3e135"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[0].versionId"
#   value: "122438658"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].createdDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[0].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[0].name"
#   value: "SOURCE_REF"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[0].sortOrder"
#   value: "1"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[0].value"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[10].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[10].name"
#   value: "ADDRESS1_LINE5"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[10].sortOrder"
#   value: "11"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[11].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[11].name"
#   value: "ADDRESS1_LINE6"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[11].sortOrder"
#   value: "12"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[12].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[12].name"
#   value: "CONCAT_ADDRESS"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[12].sortOrder"
#   value: "13"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[12].value"
#   value: "Joe Black & Jane Doe 111 A 11TH ST AAA 1A New Jersey NJ"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[13].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[13].name"
#   value: "ADDRESS1_CITY"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[13].sortOrder"
#   value: "14"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[14].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[14].name"
#   value: "ADDRESS1_STATE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[14].sortOrder"
#   value: "15"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[15].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[15].name"
#   value: "ADDRESS1_PROVINCE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[15].sortOrder"
#   value: "16"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[16].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[16].name"
#   value: "ADDRESS1_POSTALCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[16].sortOrder"
#   value: "17"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[17].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[17].name"
#   value: "ADDRESS1_ZIP5"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[17].sortOrder"
#   value: "18"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[18].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[18].name"
#   value: "ADDRESS1_ZIP4"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[18].sortOrder"
#   value: "19"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[19].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[19].name"
#   value: "ADDRESS1_COUNTRY"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[19].sortOrder"
#   value: "20"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[19].value"
#   value: "UNITED STATES OF AMERICA"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[1].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[1].name"
#   value: "UNIQUE_KEY"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[1].sortOrder"
#   value: "2"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[1].value"
#   value: "A05003324172"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[20].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[20].name"
#   value: "ADDRESS1_COUNTRYCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[20].sortOrder"
#   value: "21"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[20].value"
#   value: "USA"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[21].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[21].name"
#   value: "ADDRESS1_FOREIGNDOMESTICCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[21].sortOrder"
#   value: "22"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[21].value"
#   value: "DOMESTIC"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[22].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[22].name"
#   value: "PARTY1_DATE_OF_BIRTH"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[22].sortOrder"
#   value: "22"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[22].value"
#   value: "20/10/1963"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[2].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[2].name"
#   value: "BARCODE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[2].sortOrder"
#   value: "3"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[3].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[3].name"
#   value: "ADDRESS_TYPE"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[3].sortOrder"
#   value: "4"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[3].value"
#   value: "Plating Address"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[4].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[4].name"
#   value: "CARE_OF_TEXT"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[4].sortOrder"
#   value: "5"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[5].isScreenable"
#   value: "true"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[5].name"
#   value: "ATTENTION_TO_TEXT"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[5].sortOrder"
#   value: "6"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[6].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[6].name"
#   value: "ADDRESS1_LINE1"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[6].sortOrder"
#   value: "7"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[6].value"
#   value: "Joe Black &"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[7].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[7].name"
#   value: "ADDRESS1_LINE2"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[7].sortOrder"
#   value: "8"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[7].value"
#   value: "Jane Doe AA BBB"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[8].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[8].name"
#   value: "ADDRESS1_LINE3"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[8].sortOrder"
#   value: "9"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[8].value"
#   value: "111 A 11TH ST AAA 1A"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[9].isScreenable"
#   value: "false"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[9].name"
#   value: "ADDRESS1_LINE4"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[9].sortOrder"
#   value: "10"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].fields[9].value"
#   value: "New Jersey NJ 10011"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].masterId"
#   value: "72951854"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].status"
#   value: "A"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].uniqueCustId"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].version"
#   value: "412740c151535f0756e8dbec7440b726c7a3e135"
# }
# flat_payload {
#   key: "alertedParty.inputRecordHist.inputRecords[1].versionId"
#   value: "122438659"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.alertId"
#   value: "SANC-ASM-6434404"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.busDate"
#   value: "20211127"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.datasetName"
#   value: "R_US_Active_Address"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[0].fields.beneficiaryName"
#   value: "Pladimir Vutin"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[0].fields.branchAccountNumber"
#   value: "234_142529"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[0].fields.firstName"
#   value: "Pladimir"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[0].fields.lastName"
#   value: "Vutin"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[0].fields.srcSystemAccountKey"
#   value: "2021-01-29-13.44.57.093694"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[0].id"
#   value: "2021-01-29-13.44.57.093694"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[1].fields.beneficiaryName"
#   value: "Eva Pladimirova"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[1].fields.branchAccountNumber"
#   value: "234_142529"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[1].fields.firstName"
#   value: "Eva"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[1].fields.lastName"
#   value: "Pladimirova"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[1].fields.srcSystemAccountKey"
#   value: "2021-01-29-13.44.57.093694"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedAccounts.accounts[1].id"
#   value: "2021-01-29-13.44.57.093694"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.countryOfIncorporation"
#   value: "None"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.dobDate"
#   value: "02/31/1900"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyCountryOfBirth"
#   value: "None"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyFirstName"
#   value: "Pladimir"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyId"
#   value: "0002712291"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyLastName"
#   value: "Vutin"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyMiddleName"
#   value: "None"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyName"
#   value: "Pladimir Vutin"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyPrimaryCitizenshipCountry"
#   value: "United States"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyResidenceCountry"
#   value: "United States"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.partyType"
#   value: "Individual"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.taxId"
#   value: "154421273"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].fields.taxIdType"
#   value: "SSN"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[0].id"
#   value: "0002712291"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.countryOfIncorporation"
#   value: "None"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.dobDate"
#   value: "04/31/1910"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyCountryOfBirth"
#   value: "None"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyFirstName"
#   value: "Eva"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyId"
#   value: "0004727489"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyLastName"
#   value: "Pladimirova"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyMiddleName"
#   value: "None"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyName"
#   value: "Eva Pladimirova"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyPrimaryCitizenshipCountry"
#   value: "United States"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyResidenceCountry"
#   value: "United States"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.partyType"
#   value: "Individual"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.taxId"
#   value: "022368917"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].fields.taxIdType"
#   value: "SSN"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.relatedParties.party[1].id"
#   value: "0004727489"
# }
# flat_payload {
#   key: "alertedParty.supplementalInfo.uniqueCustId"
#   value: "R_US_Active_Address_A00170086018_2018-08-28-18.45.50.012201"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].accountSeq"
#   value: "1"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].datasetId"
#   value: "1044"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.addresses[0].address1"
#   value: "111 STREET 999"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.addresses[0].address2"
#   value: "FL;US"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.addresses[0].city"
#   value: "ATLANTA"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.addresses[0].country"
#   value: "US"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.addresses[0].countryName"
#   value: "United States of America"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.addresses[0].postalCode"
#   value: "11111"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.createdDate"
#   value: "10/16/2018"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.dobs[0].dob"
#   value: "MAY 6, 1981"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.entityType"
#   value: "03"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.id"
#   value: "908049"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.ids"
#   value: "None"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.lastUpdateDate"
#   value: "04/19/2019"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.listCode"
#   value: "-1003"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.listId"
#   value: "15991"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.name"
#   value: "Joe Ding"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.programs[0].type"
#   value: "MSSBGWM"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[0]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[1]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[2]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[3]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[4]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[5]"
#   value: "PLEASE CALL AML HOT LINE AT 212 762 8000 AND REF CI-079385"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.sdfs.sdf[6]"
#   value: "05/05/2015 19:49:26"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.source"
#   value: "CON"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entity.version"
#   value: "20150505194929"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entityId"
#   value: "908043"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entityTextType"
#   value: "UPID"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entityType"
#   value: "03"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].entityVersion"
#   value: "20150505194929"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].firstMatchedDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].inputVersionId"
#   value: "122438658"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].lastMatchedDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].lastReviewDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].masterId"
#   value: "72951854"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].masterVersion"
#   value: "412740c151535f0756e8dbec7440b726c7a3e135"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].matchId"
#   value: "66326"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].matchStatus"
#   value: "O"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].matchType"
#   value: "GWL"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].riskScore"
#   value: "-1.0"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].sourceCode"
#   value: "CON"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].stopDescriptors[0].name"
#   value: "Joe Doe"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].stopDescriptors[0].stopDescriptorDetails[0].inputSynonym"
#   value: "null"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].stopDescriptors[0].stopDescriptorDetails[0].inputToken"
#   value: "Doe"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].stopDescriptors[0].stopDescriptorDetails[0].matchScore"
#   value: "0.8571428571428572"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].stopDescriptors[0].stopDescriptorDetails[0].sdToken"
#   value: "Doe"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].stopDescriptors[0].totalMatchScore"
#   value: "0.9230769230769231"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[0].uniqueCustomerId"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].accountSeq"
#   value: "1"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].datasetId"
#   value: "1044"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.addresses.address.address1"
#   value: "111 STREET 999"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.addresses.address.address2"
#   value: "FL;US"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.addresses.address.city"
#   value: "ATLANTA"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.addresses.address.country"
#   value: "PL"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.addresses.address.countryName"
#   value: "Poland"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.addresses.address.postalCode"
#   value: "11111"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.createdDate"
#   value: "10/16/2018"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.dobs[0].dob"
#   value: "MAY 6, 1981"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.entityType"
#   value: "03"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.id"
#   value: "908044"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.ids"
#   value: "None"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.lastUpdateDate"
#   value: "04/19/2019"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.listCode"
#   value: "-1003"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.listId"
#   value: "15991"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.name"
#   value: "Joe Dong"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.programs.program.type"
#   value: "MSSBGWM"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[0]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[1]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[2]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[3]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[4]"
#   value: "N/A"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[5]"
#   value: "PLEASE CALL AML HOT LINE AT 212 762 8000 AND REF CI-079385"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.sdfs.sdf[6]"
#   value: "05/05/2015 19:49:26"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.source"
#   value: "CON"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entity.version"
#   value: "20150505194923"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entityId"
#   value: "908044"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entityTextType"
#   value: "UPID"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entityType"
#   value: "03"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].entityVersion"
#   value: "20150505194923"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].firstMatchedDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].inputVersionId"
#   value: "122438659"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].lastMatchedDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].lastReviewDate"
#   value: "01/08/20"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].masterId"
#   value: "72951854"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].masterVersion"
#   value: "412740c151535f0756e8dbec7440b726c7a3e135"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].matchId"
#   value: "38741"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].matchStatus"
#   value: "O"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].matchType"
#   value: "GWL"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].riskScore"
#   value: "-1.0"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].sourceCode"
#   value: "CON"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].stopDescriptors[0].name"
#   value: "Joe Doe"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].stopDescriptors[0].stopDescriptorDetails[0].inputSynonym"
#   value: "null"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].stopDescriptors[0].stopDescriptorDetails[0].inputToken"
#   value: "Doe"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].stopDescriptors[0].stopDescriptorDetails[0].matchScore"
#   value: "0.8571428571428572"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].stopDescriptors[0].stopDescriptorDetails[0].sdToken"
#   value: "Doe"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].stopDescriptors[0].totalMatchScore"
#   value: "0.9230769230769231"
# }
# flat_payload {
#   key: "watchlistParty.matchRecords[1].uniqueCustomerId"
#   value: "R_US_Active_Address_A05003324172_2020-01-07-07.06.28.836480"
# }
# alert_event_history: "{\"alertEventHistory\": {\"alertId\": \"SANC-ASM-60505\", \"alertInternalId\": \"2229113\", \"alertTypeId\": \"10168\", \"datasetId\": \"1044\", \"datasetName\": \"R_US_Active_Address\", \"uniqueCustId\": \"R_US_Active_Address_A05005818612_2020-11-09-09.25.28.978342\", \"busDate\": \"20211201\", \"statusId\": \"41\", \"statusName\": \"[L2 Review]\", \"eventHistory\": [{\"createDate\": \"2021-07-08 23:42:50.000000\", \"event\": \"Alert created\", \"eventNote\": \"Item identifier: SANC-ASM-JAN-AL-1\", \"userNote\": null, \"userInternalId\": \"39001\", \"loginName\": \"amlcmu\"}, {\"createDate\": \"2020-12-12 12:39:30.000000\", \"event\": \"Status changed\", \"eventNote\": \"Change step forward\\nStatus changed from [L2 Review] to [L2 Closed No Action - False Positive]. Work Item Closed\", \"userNote\": null, \"userInternalId\": \"170301\", \"loginName\": \"upadhabh\"}, {\"createDate\": \"2020-12-10 00:58:39.000000\", \"event\": \"Status changed\", \"eventNote\": \"Change step forward\\nStatus changed from [L1 Review] to [L1 Closed Action - Escalate to L2 Unable to Clear].\\nReasons added: Sources Used (3 D / 3 D Docs / EDD)\", \"userNote\": null, \"userInternalId\": \"170301\", \"loginName\": \"upadhabh\"}, {\"createDate\": \"2020-03-18 22:05:30.000000\", \"event\": \"Status changed\", \"eventNote\": \"Change step forward\\nStatus changed from [L2 New] to [L2 Review].\", \"userNote\": null, \"userInternalId\": \"170301\", \"loginName\": \"upadhabh\"}, {\"createDate\": \"2021-01-31 06:31:14.000000\", \"event\": \"Note added\", \"eventNote\": \"Note added during: Change step forward\", \"userNote\": \"Escalating from L1 to L2 - unable to clear\", \"userInternalId\": \"170301\", \"loginName\": \"upadhabh\"}, {\"createDate\": \"2021-08-24 02:50:56.000000\", \"event\": \"Note added\", \"eventNote\": \"Note added during: Change step forward\", \"userNote\": \"Can be closed as false positive\", \"userInternalId\": \"170301\", \"loginName\": \"upadhabh\"}]}}"

# %%
from random import randrange
from datetime import timedelta

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return datetime.strftime(start + timedelta(seconds=random_second), "%Y-%m-%d %H:%M:%S.%f")

# %%
from datetime import datetime

START = datetime.strptime('1/1/2020 1:30 PM', '%m/%d/%Y %I:%M %p')
END = datetime.strptime('1/1/2022 4:50 AM', '%m/%d/%Y %I:%M %p')

print(random_date(d1, d2))
# Out:
# 2021-07-12 20:16:35.000000

# %%
for i in text['alertEventHistory']['eventHistory']:
    i['createDate'] = random_date(START, END)

# %%
channel = grpc.insecure_channel("10.8.0.3:22984")

# %%
channel1 = grpc.insecure_channel("10.8.0.3:21351")

# %%
channel = grpc.insecure_channel("0.0.0.0:9091")

# %%
stub = EtlLearningServiceStub(channel)

# %%
stub.RunEtlLearning(RunEtlLearningRequest(learning_alerts=[load_alert("notebooks/sample/wm_address_in_payload_format.json") for i in range(10)]))
# Out:
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-63492"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-59418"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-21092"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-97406"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-63154"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-18069"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-99966"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-75455"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-90219"
#   etl_status: SUCCESS
# }
# etl_alerts {
#   batch_id: "1"
#   alert_id: "SANC-ASM-78010"
#   etl_status: SUCCESS
# }

# %%
stub1 = EtlLearningServiceStub(channel1)

# %%
results_from_stub.append(stub.RunEtlLearning.future(RunEtlLearningRequest(learning_alerts=[request_alert for i in range(10)])))

# %%
results_from_stub = []
for i in range(250):
    results_from_stub.append(stub.RunEtlLearning.future(RunEtlLearningRequest(learning_alerts=[load_alert("notebooks/sample/wm_address_in_payload_format.json") for i in range(10)])))

# %%
results_from_stub1 = []
for i in range(250):
    results_from_stub1.append(stub1.RunEtlLearning.future(RunEtlLearningRequest(learning_alerts=[request_alert for i in range(10)])))

# %%
results_from_stub1 = [i.result() for i in results_from_stub1]

# %%
results_from_stub = [i.result() for i in results_from_stub]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_250319/160433776.py in <module>
# ----> 1 results_from_stub = [i.result() for i in results_from_stub]
#
# /tmp/ipykernel_250319/160433776.py in <listcomp>(.0)
# ----> 1 results_from_stub = [i.result() for i in results_from_stub]
#
# AttributeError: result

# %%
len(results_from_stub)
# Out:
# 20

# %%
from google.protobuf.json_format import MessageToDict

# %%
counter = 0
for result in results_from_stub:
    result = MessageToDict(result)
    for item in result['etlAlerts']:
        assert item['etlStatus'] == 'SUCCESS'
        counter += 1

# %%
counter
# Out:
# 2500

# %%
assert counter == 10
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_250319/214008040.py in <module>
# ----> 1 assert counter == 10
#
# AssertionError:

# %%
counter = 0
for result in results_from_stub1:
    result = MessageToDict(result)
    for item in result['etlAlerts']:
        assert item['etlStatus'] == 'SUCCESS'
        counter += 1

# %%
assert counter == 2500

# %%
decompressed = lz4.frame.decompress(test.state)
# Out:
# ---------------------------------------------------
# TypeError         Traceback (most recent call last)
# <ipython-input-69-56cfc20ea28e> in <module>
# ----> 1 decompressed = lz4.frame.decompress(test.state)
#
# TypeError: a bytes-like object is required, not 'NoneType'

# %%
import lz4


from etl_pipeline.learning.proto.historical_decision_learning_pb2 import (
    Alert,
    AlertedParty,
    HistoricalDecisionLearningStoreExchangeRequest,
)
x = HistoricalDecisionLearningStoreExchangeRequest()
x.FromString(decompressed)
# Out:
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/69416"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "03e7aab451581081ba5e4d3863e0264c1db0ce5c"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "ededb57e2bfefe782debf7205df9de5e9a20c806"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "1435822ceefb2b2c592bd8e23d987eed882bffed"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/15069"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "dd3bd1d79541b7c13e3f74c125b8a1d62f6ec44e"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "100cda25fdc720732f168d975538d7e78a2e666f"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "d0b73adb22fe54fca6a14daaed4079aad7014a19"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }

# %%
new_field = field_type()
feature.agent_feature_input.Unpack(new_field)

# %%
payload = """"""

# %%
import lz4.frame

# %%
import base64
output = base64.b64decode(payload)

# %%
x = HistoricalDecisionLearningStoreExchangeRequest()
x.ParseFromString(lz4.frame.decompress(output))
# Out:
# 3432

# %%
x
# Out:
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/39966"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "902ed54dc05f4d8aaf1a9dbbcb1b52c31d5c4cd8"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "aee187dfb8b6a2f4422485a821bbdecd00fcccb4"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "14b49be40efef2f8c93d9154bb4acd1f98ed9cf1"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
# alerts {
#   alert_id: "alerts/2"
#   match_id: "alerts/2/matches/19040"
#   watchlist {
#     id: "1044"
#   }
#   alerted_party {
#     id: "A05003324172"
#   }
#   decisions {
#     id: "29f47ff192bb8774d84768ee0e1488be7b247e11"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "99dc2aab4905b8ed715150e08593fd37228e16cb"
#     created_at: 1641057943
#   }
#   decisions {
#     id: "32291919a531e7fe8d3bdc33566383acd4a6a502"
#     created_at: 1641057943
#   }
#   discriminators {
#     value: "mike_ap_id_tp_marked"
#   }
#   discriminators {
#     value: "mike_tokens_tp_marked"
#   }
#   discriminators {
#     value: "mike_ap_name_tp_marked"
#   }
# }
